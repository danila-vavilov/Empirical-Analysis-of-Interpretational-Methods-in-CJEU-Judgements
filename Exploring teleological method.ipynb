# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_style('whitegrid')
import re

# %%
df=pd.read_csv('Preliminary_database5.csv', index_col=0)
df
# Out:
#                                                   Title CELEX number  \
# 0     Judgment of the Court (Sixth Chamber) of 18 Se...  62018CJ0366
# 1     Judgment of the Court (Fifth Chamber) of 29 Ju...  62017CJ0654
# 2     Judgment of the Court (Fifth Chamber) of 23 Ma...  62017CJ0720
# 3     Judgment of the Court (First Chamber) of 8 May...  62017CJ0396
# 4     Judgment of the Court (First Chamber) of 8 May...  62017CJ0024
# ...                                                 ...          ...
# 1045  Judgment of the General Court (Third Chamber) ...  62004TJ0016
# 1046  Judgment of the General Court (Third Chamber) ...  62004TJ0016
# 1047  Judgment of the General Court (Third Chamber) ...  62005TJ0070
# 1048  Judgment of the General Court (Third Chamber) ...  62005TJ0070
# 1049  Judgment of the General Court (Third Chamber) ...  62005TJ0070
#
#          ECLI identifier                    Type of procedure      origin  \
# ...

# %%
met_1=df['Text'].str.count('objective pursued', flags=re.IGNORECASE)
met_2=df['Text'].str.count('sole objective', flags=re.IGNORECASE)
met_3=df['Text'].str.count('purpose and the nature', flags=re.IGNORECASE)
met_4=df['Text'].str.count('purpose of the directive', flags=re.IGNORECASE)
met_5=df['Text'].str.count('element of its effectiveness', flags=re.IGNORECASE)
met_6=df['Text'].str.count('objective of Article', flags=re.IGNORECASE)
met_7=df['Text'].str.count('objectives of Article', flags=re.IGNORECASE)
met_8=df['Text'].str.count('objective of Directive', flags=re.IGNORECASE)
met_9=df['Text'].str.count('objectives of Directive', flags=re.IGNORECASE)
met_10=df['Text'].str.count('objective of the EU law', flags=re.IGNORECASE)
met_11=df['Text'].str.count('objectives of the EU law', flags=re.IGNORECASE)
met_12=df['Text'].str.count('purpose is', flags=re.IGNORECASE)
met_13=df['Text'].str.count('it also has the objective', flags=re.IGNORECASE)
met_14=df['Text'].str.count('general principles of', flags=re.IGNORECASE)
met_15=df['Text'].str.count('objectives of the law', flags=re.IGNORECASE)
met_16=df['Text'].str.count('objective of the law', flags=re.IGNORECASE)
met_17=df['Text'].str.count('objectives of law', flags=re.IGNORECASE)
met_18=df['Text'].str.count('objective of law', flags=re.IGNORECASE)
met_19=df['Text'].str.count('purpose of directive', flags=re.IGNORECASE)
met_20=df['Text'].str.count('purpose of the law', flags=re.IGNORECASE)
met_21=df['Text'].str.count('purpose of law', flags=re.IGNORECASE)
met_22=df['Text'].str.count('nature of law', flags=re.IGNORECASE)
met_23=df['Text'].str.count('nature of the law', flags=re.IGNORECASE)
met_24=df['Text'].str.count('sole objective', flags=re.IGNORECASE)

met=met_1+met_2+met_3+met_4+met_5+met_6+met_7+met_8+met_9+met_10+met_11+met_12+met_13+met_14+met_15+met_16+met_17+met_18+met_19+met_20+met_21+met_22+met_23+met_24

# %%
df['occurences of teleo met']=met

# %%
df
# Out:
#                                                   Title CELEX number  \
# 0     Judgment of the Court (Sixth Chamber) of 18 Se...  62018CJ0366
# 1     Judgment of the Court (Fifth Chamber) of 29 Ju...  62017CJ0654
# 2     Judgment of the Court (Fifth Chamber) of 23 Ma...  62017CJ0720
# 3     Judgment of the Court (First Chamber) of 8 May...  62017CJ0396
# 4     Judgment of the Court (First Chamber) of 8 May...  62017CJ0024
# ...                                                 ...          ...
# 1045  Judgment of the General Court (Third Chamber) ...  62004TJ0016
# 1046  Judgment of the General Court (Third Chamber) ...  62004TJ0016
# 1047  Judgment of the General Court (Third Chamber) ...  62005TJ0070
# 1048  Judgment of the General Court (Third Chamber) ...  62005TJ0070
# 1049  Judgment of the General Court (Third Chamber) ...  62005TJ0070
#
#          ECLI identifier                    Type of procedure      origin  \
# ...

# %%
df.to_csv('Database_duplicates.csv')
